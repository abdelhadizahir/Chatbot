# %% [markdown]
# # IMPORTATION

# %%
import pandas as pd
import numpy as np
from numpy import random
import gensim
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
import matplotlib
from matplotlib import pyplot as plt
import codecs
import PyPDF2
# %matplotlib inline
import spacy
import fr_core_news_sm
nlp = spacy.load("fr_core_news_sm")
from sklearn.manifold import TSNE
from numpy import dot
from numpy.linalg import norm

# %% [markdown]
# # OPEN 2nd & 3rd pages

# %%
#open the file
pdfFileObj = open("Decret1.pdf", 'rb')
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 

# printing number of pages in pdf file 
print(pdfReader.numPages) 

# creating a page object 
pageObj = pdfReader.getPage(1) 

text = pageObj.extractText()
text2 = ''

#number_of_pages = read_pdf.getNumPages()
number_of_pages = 3
for page_number in range(1,number_of_pages):   # use xrange in Py2
    page = pdfReader.getPage(page_number)
    page_content = page.extractText()
    text2 = text2 + page_content

# extracting text from page 
print(text2) 
print('---------------------')
print('---------------------')
print(len(text))  
print(type(text))
# closing the pdf file object 
pdfFileObj.close()
# Out:
# 118
#
#
# 2
# /
# 118
#
#
#
#
# Le Chef du Gouvernement,
#
#
# Vu la constitution, notamment ses articles 72 et 90 ;
#
#
# Vu la loi n° 69
# -
#
# ses publiques et autres
# organismes, promulguée par le dahir n° 1
# -
# 03
# -
# 195 du 16 ramadan 1424 (11 novembre 2003)
# , telle que  modifiée et complétée ;
#
#
# Vu la loi n° 45
# -
#
# groupements
# promulguée par le dahir n° 1.09.02 du 22 safar 1430 (18 février 2009)
# notamment son article 55 ;
#
#
# Vu le décret n° 2
# -
# 98
# -
#
#
#
#
# Sur p
#
#
#
# Ces principes permettent d'assurer l'efficacité de la commande publique et la bonne utilisation
# des deniers publics. Ils exigent une définition préalable des besoins de l'administration, le respect
# des obligations de publicité et de mise en concurrence et le choix de l'offre économiquement la
# plus avantageuse.
#
#
#
# décret.
#
#
# Article 2 : Objet et champ d'applica
# tion
#
# Le présent décret fixe les conditions et les formes dans lesquelles sont passés les marchés de
# travaux, de fournitures et de services pour le compte  de l'Etat et des établissements publics
# figurant dans la liste fixée par arrêté du ministre chargé
#
#
# la loi n° 69
# -
# 00 susvisée telle que  modifiée et complétée.
#
#
#
# Le présent décret fixe en outre, certaines règles relatives à la gestion desdits marchés et à leur
# contrôle.
#
#
#
# rée en vigueur de la loi organique fixant le régime financier
#
#
# constitution et des textes pris pour son application , le présent décret fixe également les
# conditions et les
#
# formes dans lesquelles sont passés les marchés  de travaux, de fournitures et de
# services  pour le compte des régions, des préfectures , des provinces et des communes.
#
#
# Après avis d
# e la commission des marchés;
#
#
#
# Après délibération en
#
# Conseil du gouvernement du
#
#
#
# 1
#
# 4
#
#
# safar 1434 (28 décembre 2012),
#
#
#
#
#
# Décrète
#
#
#
# :
#
#
#
# Chapitre
#
#
#
# premier : Dispositions générales
#
#
#
# Article premier : Principes généraux
#
#
#
# La passati
# on des marchés publics obéit aux principes:
#
#
#
# -
#
#
#
# de liberté d'accès à la commande publique
#
#
#
# ;
#
#
#
# -
#
#
#
#
#
#
#
# ;
#
#
#
# -
#
#
#
# de garantie des droits des concurrents
#
#
#
# ;
#
#
#
# -
#
#
#
# de
#
#
#
# transparence dans les cho
# ix du maître d'ouvrage.
#
#
#
# Elle obéit également aux règles de bonne gouvernance.
#
#
#
#
#
# objectifs du développement durable.
#
#
#
#
#
# 3
# /
# 118
#
#
#
#
# Article 3 : Dérogations
#
# Demeurent en dehors du champ d'application du présent décr
# et:
#
#
# -
#
# les conventions ou contrats passés dans les formes et selon les règles du droit commun tels
#
# -
# dessous ;
#
#
# -
#
# les contrats de gestion déléguée de services et d'ouvrages publics ;
#
#
# -
#
# les cessions de biens entre service
#
# les provinces et les communes ;
#
#
# -
#
#
# réglementation en vigueur.
#
#
# -
#
# les contrats relatifs aux transactions financière
# s effectuées sur le marché financier
# international et les services y afférents.
#
#
# Il peut être dérogé aux dispositions du présent décret en ce qui concerne les marchés passés dans
# le cadre d'accords ou conventions que le Maroc a conclus avec des organismes
# internationaux
# ou des Etats étrangers, lorsque lesdits accords ou conventions stipulent expressément
# l'application de conditions et de formes particulières de passation des marchés.
#
#
# Article 4 : Définitions
#
# Au sens du présent décret, on entend par :
#
#
# 1
# -
#
# Attr
# ibutaire : concurrent dont l'offre a été retenue avant la notification de l'approbation du
# marché ;
#
#
# 2
# -
#
# Autorité compétente : l'ordonnateur ou la personne déléguée par lui pour approuver  le
# marché ou toute autre personne habilitée à cet effet par un texte lé
# gislatif ou réglementaire;
#
#
# 3
# -
#
# Bordereau des prix : document qui contient une décomposition par poste des prestations à
# exécuter et indique, pour chacun des postes, le prix applicable ;
#
#
# 4
# -
#
# Bordereau des prix des approvisionnements : document qui indique la lis
# te des matériaux à
# approvisionner sur le chantier et les prix unitaires correspondant ;
#
#
# 5
# -
#
# Bordereau du prix global : document qui, pour un marché à prix global, indique la prestation
# à réaliser et le prix forfaitaire  correspondant ;.
#
#
# 6
# -
#
# Concurrent : toute p
# ersonne physique ou morale qui propose une offre en vue de la conclusion
# d'un marché;
#
#
# 7
# -
#
# Conventions ou contrats de droit commun : sont des conventions ou des contrats qui ont pour
# objet soit la réalisation de prestations déjà définies quant aux conditions
# de leur fourniture et de
# leur prix et que le maître d'ouvrage ne peut modifier ou qu'il n'a pas intérêt à modifier soit la
# réalisation de prestations qui en raison de leur nature particulière peuvent être passées selon les
# règles de droit commun.
#
#
# La list
# e des prestations qui peuvent faire l'objet de contrats ou de conventions de droit commun
#
# du ministre chargé des finances sur proposition du  ministre concern
# é et  après avis de la
# commission des marchés.
#
#
# 8
# -
#
# Décomposition du montant global : document qui, pour un marché à prix global, contient une
# répartition des prestations à exécuter par poste, effectuée sur la base de la nature de ces
# prestations; ce document
#
# peut indiquer les quantités forfaitaires pour les différents postes ;
#
#
# 9
# -
#
# Détail estimatif : document qui, pour un marché à prix unitaires, contient une décomposition
# des prestations à exécuter par poste et indique, pour chaque poste, la quantité présumée et
#
# le prix
# unitaire correspondant du bordereau des prix ; le détail estimatif et le bordereau des prix peuvent
# constituer un document unique dit « bordereau des prix
# -
# détail estimatif » ;
#
#
#
# ---------------------
# ---------------------
# 2300
# <class 'str'>

# %% [markdown]
# # PRE-PROCESSING

# %%
def  r_punctuation(text):
    """ Return a cleaned version of text
    """
    text = re.sub('<[^>]*>', '', text)
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text)
    text = (re.sub('[\W]+', ' ', text.lower()) + ' ' + ' '.join(emoticons).replace('-', ''))
    return text

#text = str(pageObj)
text = r_punctuation(text2)




import unidecode
unaccented_string = unidecode.unidecode(text)



nltk.download('stopwords')
from nltk.corpus import stopwords
sw = stopwords.words('french') #pour le text en français 
#print(np.array(sw))
#print(len(np.array(sw)))
#Tokens = str(Tokens)
#print('Len before stopwords removing :' ,len(print(unaccented_string)))
print('---------------------')
print('---------------------')
def stopwords(text):
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    return " ".join(text)

stopw = stopwords(unaccented_string)





def return_token(sentence):
    # Tokeniser la phrase
    return nlp(sentence)
    # Retourner le texte de chaque token
    #return [X.text for X in doc]

TokensList = return_token(stopw)






from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer(language='french')

def return_stem(sentence):
    #doc = nlp(sentence)
    return [stemmer.stem(X.text) for X in sentence]

Stemmatized = return_stem(TokensList)






def return_POS(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner les étiquettes de chaque token
    return [(X, X.pos_) for X in doc]
Stem_for_pos = str(Stemmatized)
return_POS(Stem_for_pos)
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------
# ---------------------
# [([, 'PUNCT'),
#  (', 'PUNCT'),
#  (2, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (118, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (chef, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (gouvern, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (vu, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (constitu, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (not, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (articl, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (72, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (90, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (vu, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (loi, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (69, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (publiqu, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (autr, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (organ, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (promulgue, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (dah, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (1, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (03, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (195, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (16, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (ramadan, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (1424, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (11, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (novembr, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (2003, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (tel, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (modifie, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (complete, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (vu, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (loi, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (45, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (group, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (promulgue, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (dah, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (1, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (09, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (02, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (22, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (safar, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (1430, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (18, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (fevri, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (2009, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (not, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (articl, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (55, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (vu, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (decret, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (2, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (98, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (p, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (princip, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (permettent, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (assur, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (efficacit, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (command, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (publiqu, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (bon, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (utilis, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (deni, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (public, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (exigent, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (definit, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (prealabl, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (besoin, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (administr, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (respect, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (oblig, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (publicit, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (mis, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (concurrent, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (choix, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (offre, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (econom, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (plus, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (avantag, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (decret, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (articl, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (2, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (objet, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (champ, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (applic, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (tion, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (present, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (decret, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (fix, 'AUX'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (condit, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (form, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (lesquel, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (pass, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (march, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (traval, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (fournitur, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (servic, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (compt, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (etat, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (etabl, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (public, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (figur, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (list, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (fixe, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (arret, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (ministr, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (charg, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (loi, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (69, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (00, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (susvise, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (tel, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (modifie, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (complete, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (present, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (decret, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (fix, 'AUX'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (outr, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (certain, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (regl, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (relat, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (a, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (gestion, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (desdit, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (march, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (a, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (control, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (re, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (vigueur, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (loi, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (organ, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (fix, 'AUX'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (regim, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (financi, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (constitu, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (text, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (pris, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (appliqu, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (present, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (decret, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (fix, 'AUX'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (egal, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (condit, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (form, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (lesquel, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (pass, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (march, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (traval, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (fournitur, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (servic, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (compt, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (region, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (prefectur, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (provinc, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (commun, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (apre, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (avis, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (e, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (commiss, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (march, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (apre, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (deliber, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (conseil, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (gouvern, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (1, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (4, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (safar, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (1434, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (28, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (decembr, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (2012, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (decret, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (chapitr, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (premi, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (disposit, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (general, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (articl, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (premi, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (princip, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (general, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (passat, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (march, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (public, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (obeit, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (princip, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (libert, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (acce, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (a, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (command, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (publiqu, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (garant, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (droit, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (concurrent, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (transparent, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (cho, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (ix, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (maitr, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (ouvrag, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (obeit, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (egal, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (regl, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (bon, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (gouvern, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (object, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (developp, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (durabl, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (3, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (118, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (articl, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (3, 'NUM'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (derog, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (demeurent, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (dehor, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (champ, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (appliqu, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (present, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (decr, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (convent, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (contrat, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (pass, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (form, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (selon, 'ADP'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (regl, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (droit, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (commun, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (tel, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (dessous, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (contrat, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (gestion, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (delegue, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (servic, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (ouvrag, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (public, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (cession, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (bien, 'ADV'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (entre, 'ADP'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (servic, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (provinc, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (commun, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (reglement, 'VERB'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (vigueur, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (contrat, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (relat, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (transact, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (financier, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (effectue, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (march, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (financi, 'NOUN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (international, 'ADJ'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (servic, 'PROPN'),
#  (', 'PUNCT'),
#  (,, 'PUNCT'),
#  (', 'PUNCT'),
#  (afferent, 'ADV'),
#  (', 'PUNCT'),
#  ...]

# %% [markdown]
# # Vocabulary

# %%
vocab = set()
vocab = vocab.union(set(Stemmatized))#Set returns unique words in the sentence
                                    #Union returns the unique common elements from a two sets

vocab.add('no')
vocab.add('yes')
print(vocab)

vocab = list(vocab)

c=0
for a in vocab :
    if a == 'cahier' :
        c=c+1
print('---------------')
print('len de stemm : ', len(Stemmatized))
print('len de vocab : ', len(vocab))
print('Ocuurrence du mot : ',c)
# Out:
# {'00', 'bordereau', 'regl', 'regim', 'obeit', 'deni', 'maitr', '11', 'ministr', 'not', 'gislat', 'dehor', 'disposit', 'selon', 'chacun', 'presume', 'uniqu', 'interet', 'post', 'utilis', 'definit', 'natur', 'no', 'prefectur', 'docu', 'egal', 'publiqu', 'articl', 'provinc', 'libert', 'bien', '02', 'etranger', 'e', 'form', 'charg', 'text', 'accord', 'march', '6', 'habilite', 'gestion', '55', 'moral', 'unitair', 'cession', '2009', 'complete', 'acce', 'entend', 'decembr', 'tion', 'convent', 'group', 'gouvern', 'assur', 'respect', 'traval', 'ibutair', 'cet', '2012', 'effet', 'reglement', 'fevri', 'durabl', 'command', '3', 'publicit', 'modifie', 'passat', '9', 'efficacit', 'compt', 'dessous', 'ordon', 'avant', 'person', 'public', '98', 'condit', 'correspond', '69', 'arret', 'peut', 'commun', '2003', 'autorit', 'raison', 'proposit', '16', 'bas', 'certain', 'stipulent', 'general', 'prealabl', '8', 'defin', '195', 'dah', '18', 'princip', 'appliqu', 'execut', 'retenu', 're', 'permettent', 'susvise', 'tout', '5', 'vu', 'lesquel', 'lorsqu', 'quant', 'present', 'contrat', 'fix', 'fournitur', 'p', 'control', 'indiqu', 'dej', 'loi', 'etabl', 'realis', 'avis', 'decret', '72', 'cho', 'effectue', 'concern', 'physiqu', 'forfaitair', 'transparent', 'approb', '09', '1424', 'fixe', 'propos', 'prestat', 'outr', 'objet', 'detail', 'etre', 'afferent', 'global', 'econom', 'tel', 'chaqu', 'deliber', '2', 'financier', 'express', '4', '1434', 'approvision', 'concurrent', 'modifi', '118', 'conseil', 'apre', 'exigent', 'relat', '45', 'pris', 'decr', 'passe', 'etat', 'safar', 'champ', 'maroc', 'material', 'chef', '1430', 'besoin', 'promulgue', 'derog', 'fair', 'mont', 'servic', 'garant', 'chapitr', 'erson', 'plus', 'desdit', 'pass', 'lis', 'conclus', 'quantit', 'estim', 'a', 'list', 'oblig', 'ramadan', 'premi', 'ix', 'ouvrag', 'demeurent', 'decomposit', 'peuvent', 'transact', 'prix', 'bon', 'attr', 'ete', 'reglementair', 'dit', 'particulier', 'mis', 'financi', 'dont', 'choix', '03', 'repartit', 'yes', 'cadr', '7', 'sen', 'developp', 'droit', 'notif', 'different', 'applic', 'offre', 'object', 'entre', 'constitu', 'commiss', 'contient', 'organ', '1', 'autr', 'administr', 'approuv', 'financ', 'vigueur', '22', 'figur', 'chanti', '28', 'lesdit', 'competent', 'delegue', 'region', '90', 'international', 'avantag', 'novembr'}
# ---------------
# len de stemm :  496
# len de vocab :  247
# Ocuurrence du mot :  0

# %% [markdown]
# # N-grams

# %%
from nltk.util import ngrams
list(ngrams(TokensList, 2))
# Out:
# [(2, 118),
#  (118, chef),
#  (chef, gouvernement),
#  (gouvernement, vu),
#  (vu, constitution),
#  (constitution, notamment),
#  (notamment, articles),
#  (articles, 72),
#  (72, 90),
#  (90, vu),
#  (vu, loi),
#  (loi, 69),
#  (69, publiques),
#  (publiques, autres),
#  (autres, organismes),
#  (organismes, promulguee),
#  (promulguee, dahir),
#  (dahir, 1),
#  (1, 03),
#  (03, 195),
#  (195, 16),
#  (16, ramadan),
#  (ramadan, 1424),
#  (1424, 11),
#  (11, novembre),
#  (novembre, 2003),
#  (2003, telle),
#  (telle, modifiee),
#  (modifiee, completee),
#  (completee, vu),
#  (vu, loi),
#  (loi, 45),
#  (45, groupements),
#  (groupements, promulguee),
#  (promulguee, dahir),
#  (dahir, 1),
#  (1, 09),
#  (09, 02),
#  (02, 22),
#  (22, safar),
#  (safar, 1430),
#  (1430, 18),
#  (18, fevrier),
#  (fevrier, 2009),
#  (2009, notamment),
#  (notamment, article),
#  (article, 55),
#  (55, vu),
#  (vu, decret),
#  (decret, 2),
#  (2, 98),
#  (98, p),
#  (p, principes),
#  (principes, permettent),
#  (permettent, assurer),
#  (assurer, efficacite),
#  (efficacite, commande),
#  (commande, publique),
#  (publique, bonne),
#  (bonne, utilisation),
#  (utilisation, deniers),
#  (deniers, publics),
#  (publics, exigent),
#  (exigent, definition),
#  (definition, prealable),
#  (prealable, besoins),
#  (besoins, administration),
#  (administration, respect),
#  (respect, obligations),
#  (obligations, publicite),
#  (publicite, mise),
#  (mise, concurrence),
#  (concurrence, choix),
#  (choix, offre),
#  (offre, economiquement),
#  (economiquement, plus),
#  (plus, avantageuse),
#  (avantageuse, decret),
#  (decret, article),
#  (article, 2),
#  (2, objet),
#  (objet, champ),
#  (champ, applica),
#  (applica, tion),
#  (tion, present),
#  (present, decret),
#  (decret, fixe),
#  (fixe, conditions),
#  (conditions, formes),
#  (formes, lesquelles),
#  (lesquelles, passes),
#  (passes, marches),
#  (marches, travaux),
#  (travaux, fournitures),
#  (fournitures, services),
#  (services, compte),
#  (compte, etat),
#  (etat, etablissements),
#  (etablissements, publics),
#  (publics, figurant),
#  (figurant, liste),
#  (liste, fixee),
#  (fixee, arrete),
#  (arrete, ministre),
#  (ministre, charge),
#  (charge, loi),
#  (loi, 69),
#  (69, 00),
#  (00, susvisee),
#  (susvisee, telle),
#  (telle, modifiee),
#  (modifiee, completee),
#  (completee, present),
#  (present, decret),
#  (decret, fixe),
#  (fixe, outre),
#  (outre, certaines),
#  (certaines, regles),
#  (regles, relatives),
#  (relatives, a),
#  (a, gestion),
#  (gestion, desdits),
#  (desdits, marches),
#  (marches, a),
#  (a, controle),
#  (controle, ree),
#  (ree, vigueur),
#  (vigueur, loi),
#  (loi, organique),
#  (organique, fixant),
#  (fixant, regime),
#  (regime, financier),
#  (financier, constitution),
#  (constitution, textes),
#  (textes, pris),
#  (pris, application),
#  (application, present),
#  (present, decret),
#  (decret, fixe),
#  (fixe, egalement),
#  (egalement, conditions),
#  (conditions, formes),
#  (formes, lesquelles),
#  (lesquelles, passes),
#  (passes, marches),
#  (marches, travaux),
#  (travaux, fournitures),
#  (fournitures, services),
#  (services, compte),
#  (compte, regions),
#  (regions, prefectures),
#  (prefectures, provinces),
#  (provinces, communes),
#  (communes, apres),
#  (apres, avis),
#  (avis, e),
#  (e, commission),
#  (commission, marches),
#  (marches, apres),
#  (apres, deliberation),
#  (deliberation, conseil),
#  (conseil, gouvernement),
#  (gouvernement, 1),
#  (1, 4),
#  (4, safar),
#  (safar, 1434),
#  (1434, 28),
#  (28, decembre),
#  (decembre, 2012),
#  (2012, decrete),
#  (decrete, chapitre),
#  (chapitre, premier),
#  (premier, dispositions),
#  (dispositions, generales),
#  (generales, article),
#  (article, premier),
#  (premier, principes),
#  (principes, generaux),
#  (generaux, passati),
#  (passati, marches),
#  (marches, publics),
#  (publics, obeit),
#  (obeit, principes),
#  (principes, liberte),
#  (liberte, acces),
#  (acces, a),
#  (a, commande),
#  (commande, publique),
#  (publique, garantie),
#  (garantie, droits),
#  (droits, concurrents),
#  (concurrents, transparence),
#  (transparence, cho),
#  (cho, ix),
#  (ix, maitre),
#  (maitre, ouvrage),
#  (ouvrage, obeit),
#  (obeit, egalement),
#  (egalement, regles),
#  (regles, bonne),
#  (bonne, gouvernance),
#  (gouvernance, objectifs),
#  (objectifs, developpement),
#  (developpement, durable),
#  (durable, 3),
#  (3, 118),
#  (118, article),
#  (article, 3),
#  (3, derogations),
#  (derogations, demeurent),
#  (demeurent, dehors),
#  (dehors, champ),
#  (champ, application),
#  (application, present),
#  (present, decr),
#  (decr, conventions),
#  (conventions, contrats),
#  (contrats, passes),
#  (passes, formes),
#  (formes, selon),
#  (selon, regles),
#  (regles, droit),
#  (droit, commun),
#  (commun, tels),
#  (tels, dessous),
#  (dessous, contrats),
#  (contrats, gestion),
#  (gestion, deleguee),
#  (deleguee, services),
#  (services, ouvrages),
#  (ouvrages, publics),
#  (publics, cessions),
#  (cessions, biens),
#  (biens, entre),
#  (entre, service),
#  (service, provinces),
#  (provinces, communes),
#  (communes, reglementation),
#  (reglementation, vigueur),
#  (vigueur, contrats),
#  (contrats, relatifs),
#  (relatifs, transactions),
#  (transactions, financiere),
#  (financiere, effectuees),
#  (effectuees, marche),
#  (marche, financier),
#  (financier, international),
#  (international, services),
#  (services, afferents),
#  (afferents, peut),
#  (peut, etre),
#  (etre, deroge),
#  (deroge, dispositions),
#  (dispositions, present),
#  (present, decret),
#  (decret, concerne),
#  (concerne, marches),
#  (marches, passes),
#  (passes, cadre),
#  (cadre, accords),
#  (accords, conventions),
#  (conventions, maroc),
#  (maroc, a),
#  (a, conclus),
#  (conclus, organismes),
#  (organismes, internationaux),
#  (internationaux, etats),
#  (etats, etrangers),
#  (etrangers, lorsque),
#  (lorsque, lesdits),
#  (lesdits, accords),
#  (accords, conventions),
#  (conventions, stipulent),
#  (stipulent, expressement),
#  (expressement, application),
#  (application, conditions),
#  (conditions, formes),
#  (formes, particulieres),
#  (particulieres, passation),
#  (passation, marches),
#  (marches, article),
#  (article, 4),
#  (4, definitions),
#  (definitions, sens),
#  (sens, present),
#  (present, decret),
#  (decret, entend),
#  (entend, 1),
#  (1, attr),
#  (attr, ibutaire),
#  (ibutaire, concurrent),
#  (concurrent, dont),
#  (dont, offre),
#  (offre, a),
#  (a, ete),
#  (ete, retenue),
#  (retenue, avant),
#  (avant, notification),
#  (notification, approbation),
#  (approbation, marche),
#  (marche, 2),
#  (2, autorite),
#  (autorite, competente),
#  (competente, ordonnateur),
#  (ordonnateur, personne),
#  (personne, deleguee),
#  (deleguee, approuver),
#  (approuver, marche),
#  (marche, toute),
#  (toute, autre),
#  (autre, personne),
#  (personne, habilitee),
#  (habilitee, a),
#  (a, cet),
#  (cet, effet),
#  (effet, texte),
#  (texte, gislatif),
#  (gislatif, reglementaire),
#  (reglementaire, 3),
#  (3, bordereau),
#  (bordereau, prix),
#  (prix, document),
#  (document, contient),
#  (contient, decomposition),
#  (decomposition, poste),
#  (poste, prestations),
#  (prestations, a),
#  (a, executer),
#  (executer, indique),
#  (indique, chacun),
#  (chacun, postes),
#  (postes, prix),
#  (prix, applicable),
#  (applicable, 4),
#  (4, bordereau),
#  (bordereau, prix),
#  (prix, approvisionnements),
#  (approvisionnements, document),
#  (document, indique),
#  (indique, lis),
#  (lis, materiaux),
#  (materiaux, a),
#  (a, approvisionner),
#  (approvisionner, chantier),
#  (chantier, prix),
#  (prix, unitaires),
#  (unitaires, correspondant),
#  (correspondant, 5),
#  (5, bordereau),
#  (bordereau, prix),
#  (prix, global),
#  (global, document),
#  (document, marche),
#  (marche, a),
#  (a, prix),
#  (prix, global),
#  (global, indique),
#  (indique, prestation),
#  (prestation, a),
#  (a, realiser),
#  (realiser, prix),
#  (prix, forfaitaire),
#  (forfaitaire, correspondant),
#  (correspondant, 6),
#  (6, concurrent),
#  (concurrent, toute),
#  (toute, p),
#  (p, ersonne),
#  (ersonne, physique),
#  (physique, morale),
#  (morale, propose),
#  (propose, offre),
#  (offre, vue),
#  (vue, conclusion),
#  (conclusion, marche),
#  (marche, 7),
#  (7, conventions),
#  (conventions, contrats),
#  (contrats, droit),
#  (droit, commun),
#  (commun, conventions),
#  (conventions, contrats),
#  (contrats, objet),
#  (objet, realisation),
#  (realisation, prestations),
#  (prestations, deja),
#  (deja, definies),
#  (definies, quant),
#  (quant, conditions),
#  (conditions, fourniture),
#  (fourniture, prix),
#  (prix, maitre),
#  (maitre, ouvrage),
#  (ouvrage, peut),
#  (peut, modifier),
#  (modifier, a),
#  (a, interet),
#  (interet, a),
#  (a, modifier),
#  (modifier, realisation),
#  (realisation, prestations),
#  (prestations, raison),
#  (raison, nature),
#  (nature, particuliere),
#  (particuliere, peuvent),
#  (peuvent, etre),
#  (etre, passees),
#  (passees, selon),
#  (selon, regles),
#  (regles, droit),
#  (droit, commun),
#  (commun, list),
#  (list, e),
#  (e, prestations),
#  (prestations, peuvent),
#  (peuvent, faire),
#  (faire, objet),
#  (objet, contrats),
#  (contrats, conventions),
#  (conventions, droit),
#  (droit, commun),
#  (commun, ministre),
#  (ministre, charge),
#  (charge, finances),
#  (finances, proposition),
#  (proposition, ministre),
#  (ministre, concern),
#  (concern, e),
#  (e, apres),
#  (apres, avis),
#  (avis, commission),
#  (commission, marches),
#  (marches, 8),
#  (8, decomposition),
#  (decomposition, montant),
#  (montant, global),
#  (global, document),
#  (document, marche),
#  (marche, a),
#  (a, prix),
#  (prix, global),
#  (global, contient),
#  (contient, repartition),
#  (repartition, prestations),
#  (prestations, a),
#  (a, executer),
#  (executer, poste),
#  (poste, effectuee),
#  (effectuee, base),
#  (base, nature),
#  (nature, prestations),
#  (prestations, document),
#  (document, peut),
#  (peut, indiquer),
#  (indiquer, quantites),
#  (quantites, forfaitaires),
#  (forfaitaires, differents),
#  (differents, postes),
#  (postes, 9),
#  (9, detail),
#  (detail, estimatif),
#  (estimatif, document),
#  (document, marche),
#  (marche, a),
#  (a, prix),
#  (prix, unitaires),
#  (unitaires, contient),
#  (contient, decomposition),
#  (decomposition, prestations),
#  (prestations, a),
#  (a, executer),
#  (executer, poste),
#  (poste, indique),
#  (indique, chaque),
#  (chaque, poste),
#  (poste, quantite),
#  (quantite, presumee),
#  (presumee, prix),
#  (prix, unitaire),
#  (unitaire, correspondant),
#  (correspondant, bordereau),
#  (bordereau, prix),
#  (prix, detail),
#  (detail, estimatif),
#  (estimatif, bordereau),
#  (bordereau, prix),
#  (prix, peuvent),
#  (peuvent, constituer),
#  (constituer, document),
#  (document, unique),
#  (unique, dit),
#  (dit, bordereau),
#  (bordereau, prix),
#  (prix, detail),
#  (detail, estimatif)]

# %% [markdown]
# # TF-idf   (for choosing the medium fraquency n-grams)

# %%
'''from sklearn.feature_extraction.text import TfidfVectorizer 
tfidf  = TfidfVectorizer(min_df=2, max_df=0.5, ngram_range=(1,2))
features = tfidf.fit_transform(Stemmatized)
df = pd.DataFrame(
    features.todense(),
    columns=tfidf.get_feature_names()
)
print (df.iloc[ 0:22 , : ])'''
# Out:
# 'from sklearn.feature_extraction.text import TfidfVectorizer \ntfidf  = TfidfVectorizer(min_df=2, max_df=0.5, ngram_range=(1,2))\nfeatures = tfidf.fit_transform(Stemmatized)\ndf = pd.DataFrame(\n    features.todense(),\n    columns=tfidf.get_feature_names()\n)\nprint (df.iloc[ 0:22 , : ])'

# %% [markdown]
# # Word2vec by gensim

# %%
# sg : CBOW(0) --- Skip gram (1)
from gensim.models import Word2Vec
model = Word2Vec([vocab], min_count=1,size= 50,workers=3, window =3, sg = 0)  
#model = Word2Vec([features], min_count=1,size= 50,workers=3, window =3, sg = 1)

# %%
model['region']
# Out:
# DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead). [ipykernel_launcher.py:1]
# array([ 0.0021117 ,  0.00997743,  0.00994398, -0.00410911,  0.00096175,
#         0.00962291,  0.00175603,  0.00859407, -0.00328456, -0.00908551,
#        -0.00116882,  0.00760361, -0.00654561,  0.00646435, -0.00660725,
#         0.0021897 ,  0.00741748,  0.00187825,  0.00692102, -0.00562657,
#         0.0014315 ,  0.00097238,  0.0034711 , -0.00213497,  0.00066707,
#         0.00279355,  0.00940735, -0.00652707, -0.00516898, -0.00087349,
#         0.00265278, -0.00468609,  0.00469515,  0.00425481,  0.00518032,
#         0.00602717, -0.00514822, -0.00804531,  0.00111624, -0.00380901,
#         0.00649523, -0.00423319,  0.00225475, -0.00174206,  0.00157917,
#         0.00391366,  0.00931312,  0.00646594, -0.00998206,  0.00875963],
#       dtype=float32)

# %%
#model['provinc']
model.similarity('region', 'provinc')
# Out:
# DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead). [ipykernel_launcher.py:2]
# -0.20571338

# %%
model.most_similar('region')[:5]
# Out:
# DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead). [ipykernel_launcher.py:1]
# [('realis', 0.4039234519004822),
#  ('pris', 0.33678963780403137),
#  ('obeit', 0.330180287361145),
#  ('fixe', 0.29632219672203064),
#  ('premi', 0.2770937383174896)]

# %% [markdown]
# # Similarity based on cosine

# %%
def cosine_distance (model, word,target_list , num) :
    cosine_dict ={}
    word_list = []
    a = model[word]
    for item in target_list :
        if item != word :
            b = model [item]
            cos_sim = dot(a, b)/(norm(a)*norm(b))
            cosine_dict[item] = cos_sim
    dist_sort=sorted(cosine_dict.items(), key=lambda dist: dist[1],reverse = True) ## in Descedning order 
    for item in dist_sort:
        word_list.append((item[0], item[1]))
    return word_list[0:num]
# Show the most similar Mercedes-Benz SLK-Class by cosine distance 
cosine_distance (model,'region',[vocab],5)
# Out:
# DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead). [ipykernel_launcher.py:4]
# DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead). [ipykernel_launcher.py:7]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-3b94479ab2cd> in <module>
#      13     return word_list[0:num]
#      14 # Show the most similar Mercedes-Benz SLK-Class by cosine distance
# ---> 15 cosine_distance (model,'region',[vocab],5)
#
# <ipython-input-26-3b94479ab2cd> in cosine_distance(model, word, target_list, num)
#       6         if item != word :
#       7             b = model [item]
# ----> 8             cos_sim = dot(a, b)/(norm(a)*norm(b))
#       9             cosine_dict[item] = cos_sim
#      10     dist_sort=sorted(cosine_dict.items(), key=lambda dist: dist[1],reverse = True) ## in Descedning order
#
# /opt/conda/lib/python3.7/site-packages/keras/layers/merge.py in dot(inputs, axes, normalize, **kwargs)
#     666         A tensor, the dot product of the samples from the inputs.
#     667     """
# --> 668     return Dot(axes=axes, normalize=normalize, **kwargs)(inputs)
#
# /opt/conda/lib/python3.7/site-packages/keras/layers/merge.py in __init__(self, axes, normalize, **kwargs)
#     436         if not isinstance(axes, int):
#     437             if not isinstance(axes, (list, tuple)):
# --> 438                 raise TypeError('Invalid type for `axes` - '
#     439                                 'should be a list or an int.')
#     440             if len(axes) != 2:
#
# TypeError: Invalid type for `axes` - should be a list or an int.

# %% [markdown]
# # T-SNE Visualization

# %%
def display_closestwords_tsnescatterplot(model, word, size):
    
        arr = np.empty((0,size), dtype='f')
        word_labels = [word]
        close_words = model.similar_by_word(word)
        arr = np.append(arr, np.array([model[word]]), axis=0)
        for wrd_score in close_words:
            wrd_vector = model[wrd_score[0]]
            word_labels.append(wrd_score[0])
            arr = np.append(arr, np.array([wrd_vector]), axis=0)

        tsne = TSNE(n_components=2, random_state=0)
        np.set_printoptions(suppress=True)
        Y = tsne.fit_transform(arr)
        x_coords = Y[:, 0]
        y_coords = Y[:, 1]
        plt.scatter(x_coords, y_coords)
        for label, x, y in zip(word_labels, x_coords, y_coords):
            plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
            plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
            plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
            plt.show()
display_closestwords_tsnescatterplot(model, 'prix', 50)
# Out:
# DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead). [ipykernel_launcher.py:5]
# DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead). [ipykernel_launcher.py:6]
# DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead). [ipykernel_launcher.py:8]

# %%
question = Input((max_question_len,batch_size))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-59330347e191> in <module>
# ----> 1 question = Input((max_question_len,batch_size))
#
# NameError: name 'max_question_len' is not defined

# %%
#Create input encoder A:
input_encoder_m = Sequential()
input_encoder_m.add(Embedding(input_dim=vocab_len,output_dim = 64)) 
input_encoder_m.add(Dropout(0.3))#Outputs: (Samples, story_maxlen,embedding_dim) -- Gives a list of #the lenght of the samples where each item has the
#lenght of the max story lenght and every word is embedded in the embbeding dimension
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fae686ce72fd> in <module>
#       1 #Create input encoder A:
#       2 input_encoder_m = Sequential()
# ----> 3 input_encoder_m.add(Embedding(input_dim=vocab_len,output_dim = 64))
#       4 input_encoder_m.add(Dropout(0.3))#Outputs: (Samples, story_maxlen,embedding_dim) -- Gives a list of #the lenght of the samples where each item has the
#       5 #lenght of the max story lenght and every word is embedded in the embbeding dimension
#
# NameError: name 'vocab_len' is not defined

# %%
import pickle

# %%
with open('test_qa.txt', 'rb') as f:
    test_data = pickle.load(f)

# %%
print (len(test_data))
# Out:
# 1000

# %% [markdown]
# # Building the Network

# %%
pip list | grep -i keras
# Out:
# Keras                    2.3.1
# Keras-Applications       1.0.8
# Keras-Preprocessing      1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras --upgrade --log ./pip-keras.log
# Out:
# Requirement already up-to-date: keras in /opt/conda/lib/python3.7/site-packages (2.3.1)
# Requirement already satisfied, skipping upgrade: pyyaml in /opt/conda/lib/python3.7/site-packages (from keras) (5.3.1)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /opt/conda/lib/python3.7/site-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras) (1.18.1)
# Requirement already satisfied, skipping upgrade: h5py in /opt/conda/lib/python3.7/site-packages (from keras) (2.10.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /opt/conda/lib/python3.7/site-packages (from keras) (1.4.1)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from keras) (1.1.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from keras) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Imports
from keras.models import Sequential, Model
from keras.layers.embeddings import Embedding
from keras.layers import Input, Activation, Dense, Permute, Dropout, add, dot, concatenate, LSTM

# %%
# We need to create the placeholders 
#The Input function is used to create a keras tensor
#PLACEHOLDER shape = (max_story_len,batch_size)
#These are our placeholder for the inputs, ready to recieve batches of the stories and the questions
input_sequence = Input((200,)) #As we dont know batch size yet
question = Input((200,))

# %%
#Create input encoder M:
input_encoder_m = Sequential()
input_encoder_m.add(Embedding(input_dim=vocab_len,output_dim = 64)) #From paper
input_encoder_m.add(Dropout(0.3))

#Outputs: (Samples, story_maxlen,embedding_dim) -- Gives a list of the lenght of the samples where each item has the
#lenght of the max story lenght and every word is embedded in the embbeding dimension
